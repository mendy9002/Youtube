# %%
from apiclient.discovery import build

# arguments to be passed to build function
DEVELOPER_KEY = "AIzaSyCDQHD9GIVtbuYDgorDef4fs0eihln_98E"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# creating youtube resource object for interacting with API
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)


def video_details(video_id):

    # Call the videos.list method to retrieve video info
    result = youtube.videos().list(
        id = video_id,
        part = "id,snippet,contentDetails,statistics",
    ).execute()
    
    # Extracting required info about video
    video = {}
    video['title'] = result['items'][0]['snippet']['title']
    video['tags'] = result['items'][0]['snippet']['tags']
    video['descr'] = result['items'][0]['snippet']['description']
    video['content'] = result['items'][0]['contentDetails']
    video['stats'] = result['items'][0]['statistics']
    
    return video
    

def video_comments(video_id, max_results = 1000):
    
    # Call the comments.list method to retrieve video comments
    results = youtube.commentThreads().list(
        videoId = video_id,
        part = "id,snippet,replies",
        order = "relevance",
        textFormat = "plainText",
        maxResults = max_results%101
    ).execute()

    comments = []
    
    # Extracting required info from each result
    for result in results['items']:
        comment = {}
        comment['id'] = result['id']
        comment['etag'] = result['etag']
        # comment['snippet'] = result['snippet']
        comment['authorDisplayName'] = result['snippet']['topLevelComment']['snippet']['authorDisplayName']
        comment['text'] = result['snippet']['topLevelComment']['snippet']['textOriginal']
        comment['likes'] = result['snippet']['topLevelComment']['snippet']['likeCount']
        comment['publishedtime'] = result['snippet']['topLevelComment']['snippet']['publishedAt']
        comment['updatedttime'] = result['snippet']['topLevelComment']['snippet']['updatedAt']
        comments.append(comment)
    
    return comments
    

if __name__ == "__main__":
    video_id = "gdhYD1WQKyM"
    
    details = video_details(video_id)
    comments = video_comments(video_id)
    
    print(comments)
# Out:
# [{'id': 'Ugyy05Wbe1dhasPUh9N4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/JolWYcsB6mvnCt5fhcQcVxxdY1I"', 'authorDisplayName': 'Dorahuang Tseng', 'text': '唐！\n韓的堅定支持者，\n有共同特質，\n努力、愛家、愛國家！', 'likes': 13, 'publishedtime': '2019-06-16T16:26:55.000Z', 'updatedttime': '2019-06-16T16:26:55.000Z'}, {'id': 'UgxUNIgEnJlmezA6QE54AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/km0jEyW71j6nXQ9tiAgc64clI9E"', 'authorDisplayName': 'joanne lin', 'text': '每天就是進來按倒讚', 'likes': 10, 'publishedtime': '2019-06-16T17:24:01.000Z', 'updatedttime': '2019-06-16T17:24:01.000Z'}, {'id': 'Ugyt02szINT5L0iaARJ4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/EQD_afHM-vIQcloQ5QWiB0rTpsw"', 'authorDisplayName': 'Mae', 'text': '這一次派系支持誰，不是上面的人決定得了，是由下而上選民要求議員，議員要求派糸大老支持韓國瑜。你們不支持韓市長，所以你們不懂，也或許你們懂，只是故意不說', 'likes': 5, 'publishedtime': '2019-06-16T20:44:23.000Z', 'updatedttime': '2019-06-16T20:44:23.000Z'}, {'id': 'UgyNOsyG0hq2K1RWS7h4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/b37qXJdNyCJA5_mD0xfA3ZmccDU"', 'authorDisplayName': 'Tseung To', 'text': '唯一支持韓國瑜 加油💪', 'likes': 15, 'publishedtime': '2019-06-16T13:19:46.000Z', 'updatedttime': '2019-06-16T13:19:46.000Z'}, {'id': 'UgybILkzssjXIiA-U1p4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/M5mIh7_xpW_eUp3rXoVpZqNeNcs"', 'authorDisplayName': '陳政賢', 'text': '這個節目這樣修理 韓總 跟 韓粉，如果真的是 郭台銘 過初選，就千萬不要厚著臉皮求韓粉....', 'likes': 11, 'publishedtime': '2019-06-16T19:13:37.000Z', 'updatedttime': '2019-06-16T19:13:37.000Z'}, {'id': 'UgyOoLbmdQdbMX9KHFx4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/PCFVn17IT8-svdgyQTGBPR8XptA"', 'authorDisplayName': '洁玉', 'text': '你們有沒有心？！', 'likes': 4, 'publishedtime': '2019-06-16T13:00:36.000Z', 'updatedttime': '2019-06-16T13:00:36.000Z'}, {'id': 'UgzJrpx7It6OZ0s8Edp4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/8w70Rvk8gXl1rRBEp2G-hYrVWhs"', 'authorDisplayName': 'modric19', 'text': '这是奏哀乐吗', 'likes': 5, 'publishedtime': '2019-06-16T12:08:16.000Z', 'updatedttime': '2019-06-16T12:08:16.000Z'}, {'id': 'Ugz4DDRrl0IC3VIoirZ4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/XdgnYBPbIoLuZN7lKKYDzWNijTo"', 'authorDisplayName': 'le o Loaf', 'text': '為什麼要處理非韓不投？不投犯法？那投柯文哲或者小英好了？', 'likes': 3, 'publishedtime': '2019-06-16T21:39:03.000Z', 'updatedttime': '2019-06-16T21:39:03.000Z'}, {'id': 'Ugx6jDRDEJdlmBpG1c54AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/zLV6Qp_B94sYh3Bm1pWGCWNRUxo"', 'authorDisplayName': '你父亲和你1450的野爹', 'text': '呆湾天天大肠花该多好', 'likes': 4, 'publishedtime': '2019-06-16T11:32:57.000Z', 'updatedttime': '2019-06-16T11:32:57.000Z'}, {'id': 'UgxYsdHpgFXYbk9qZ4p4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/CsI_Ukii62bDvKJ9j65wseMci5M"', 'authorDisplayName': 'jackall', 'text': '非韓不投，有郭不投💪\n我的權力我的自由', 'likes': 16, 'publishedtime': '2019-06-16T16:07:48.000Z', 'updatedttime': '2019-06-16T16:07:48.000Z'}, {'id': 'UgzAtBVz9ykodMr16SF4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/f34SPU4VDj2DxojdU5J4iAsMXqw"', 'authorDisplayName': '秦飛', 'text': '趙先生有機會當副總統，只要韓粉們全部投向郭董的懷抱……', 'likes': 3, 'publishedtime': '2019-06-16T21:51:41.000Z', 'updatedttime': '2019-06-16T21:51:41.000Z'}, {'id': 'UgzmkcWcJLJuyXO_UoZ4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/ECyhTfNrALErNakOv2LpNruzrIo"', 'authorDisplayName': 'hj u', 'text': '大佬智商压制 已经不能跟非理性的人讲正常沟通了', 'likes': 1, 'publishedtime': '2019-06-16T20:41:19.000Z', 'updatedttime': '2019-06-16T20:41:19.000Z'}, {'id': 'UgwHuV2lEcbJnuUQDoh4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/3EKi0SXySUZedkxkW-eu_-yLYzI"', 'authorDisplayName': 'Jhe Sih', 'text': '郭台銘再繼續抹紅，我相信蔡旺旺也會開始報郭台銘大陸的黑資料了，不是不爆時候未到而已。\n\n一旦過初選，一碰到大陸，年輕人又跑走了，又得罪韓支持者，傻b戰略。', 'likes': 1, 'publishedtime': '2019-06-16T22:44:26.000Z', 'updatedttime': '2019-06-16T22:48:38.000Z'}, {'id': 'UgxeOFlGBsKXoMKKThJ4AaABAg', 'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/_AzOjrGiGu1_3C_EDmylt3LE3ws"', 'authorDisplayName': 'Jessy Tsai', 'text': '國民黨自己打自己打到趴，韓市長怎麼做大家都有話講，只能等到明年票開出來就知道了', 'likes': 17, 'publishedtime': '2019-06-16T06:01:30.000Z', 'updatedttime': '2019-06-16T06:01:30.000Z'}, {'id': 'Ugw0AOpThxN98bRSGuV4AaABAg', 'etag': '"B ...
