# %%
import urllib
import json
from apiclient.discovery import build

# arguments to be passed to build function
DEVELOPER_KEY = "AIzaSyAmLjgXOGZfbCcdn27S-O7y9Y8RgPg3br4"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# creating youtube resource object for interacting with API
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)


def get_all_video_in_channel(channel_id):

    base_video_url = 'https://www.youtube.com/watch?v='
    base_search_url = 'https://www.googleapis.com/youtube/v3/search?'

    first_url = base_search_url+'key={}&channelId={}&part=snippet,id&order=date&maxResults=25'.format(DEVELOPER_KEY, channel_id)

    video_links = []
    url = first_url
    while True:
        # inp = urllib.urlopen(url)
        with urllib.request.urlopen(url) as url:
            s = url.read()
        resp = json.loads(s)

        for i in resp['items']:
            if i['id']['kind'] == "youtube#video":
                video_links.append(base_video_url + i['id']['videoId'])

        try:
            next_page_token = resp['nextPageToken']
            url = first_url + '&pageToken={}'.format(next_page_token)
        except:
            break
    return video_links

# %%
video_list = get_all_video_in_channel("UCLZBXiS9ZrIXgKBs_SMfGBQ")
print(video_list)
# Out:
# ['https://www.youtube.com/watch?v=IaatZ0FMyww', 'https://www.youtube.com/watch?v=ZZvvA6Vqrsc', 'https://www.youtube.com/watch?v=g8OODOJBnFA', 'https://www.youtube.com/watch?v=0LhRIPIit1g', 'https://www.youtube.com/watch?v=P0yhi2MBiCI', 'https://www.youtube.com/watch?v=gdhYD1WQKyM', 'https://www.youtube.com/watch?v=46wkZUMioLc', 'https://www.youtube.com/watch?v=kvk8a3Moyw0', 'https://www.youtube.com/watch?v=JSJ0EluK0xs', 'https://www.youtube.com/watch?v=R8itK_bieGQ', 'https://www.youtube.com/watch?v=MmQVSroDoAM', 'https://www.youtube.com/watch?v=boqVH241wIM', 'https://www.youtube.com/watch?v=l3WEH3FcvQY', 'https://www.youtube.com/watch?v=X46BPiEU2O4', 'https://www.youtube.com/watch?v=elWWGD5K9ME', 'https://www.youtube.com/watch?v=YAagpWfr_vk', 'https://www.youtube.com/watch?v=TGjfNDshXYI', 'https://www.youtube.com/watch?v=mWs-vydiWgo', 'https://www.youtube.com/watch?v=de3mVE02zWs', 'https://www.youtube.com/watch?v=pI5-vsqjtrw', 'https://www.youtube.com/watch?v=DaOJX0iFAhM', 'https://www.youtube.com/watch?v=0Dn6fumyV54', 'https://www.youtube.com/watch?v=pXVRZlCBDi8', 'https://www.youtube.com/watch?v=0D1Bic-zwnE', 'https://www.youtube.com/watch?v=GD1mrDrBPcQ', 'https://www.youtube.com/watch?v=o5SavKIeeE0', 'https://www.youtube.com/watch?v=hEHJivXoXVQ', 'https://www.youtube.com/watch?v=Ky2dWDz1glk', 'https://www.youtube.com/watch?v=DzgRN-znpZw', 'https://www.youtube.com/watch?v=KdnieOzr5eY', 'https://www.youtube.com/watch?v=ooj0TbRzVTk', 'https://www.youtube.com/watch?v=_fBWoggNzIc', 'https://www.youtube.com/watch?v=VBtPiqHV7mE', 'https://www.youtube.com/watch?v=vf